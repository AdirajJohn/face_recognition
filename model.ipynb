# %% [markdown]
# ### Face Detection

# %% [markdown]
# #### Import Necessary Library

# %%
import cv2
from ultralytics import YOLO

# %% [markdown]
# #### Load the pretrained model

# %%
model = YOLO('yolov8m.yaml').load('yolov8m.pt')  # build from YAML and transfer weights
# Out:
#                    from  n    params  module                                       arguments
#   0                  -1  1      1392  ultralytics.nn.modules.conv.Conv             [3, 48, 3, 2]
#   1                  -1  1     41664  ultralytics.nn.modules.conv.Conv             [48, 96, 3, 2]
#   2                  -1  2    111360  ultralytics.nn.modules.block.C2f             [96, 96, 2, True]
#   3                  -1  1    166272  ultralytics.nn.modules.conv.Conv             [96, 192, 3, 2]
#   4                  -1  4    813312  ultralytics.nn.modules.block.C2f             [192, 192, 4, True]
#   5                  -1  1    664320  ultralytics.nn.modules.conv.Conv             [192, 384, 3, 2]
#   6                  -1  4   3248640  ultralytics.nn.modules.block.C2f             [384, 384, 4, True]
#   7                  -1  1   1991808  ultralytics.nn.modules.conv.Conv             [384, 576, 3, 2]
#   8                  -1  2   3985920  ultralytics.nn.modules.block.C2f             [576, 576, 2, True]
#   9                  -1  1    831168  ultralytics.nn.modules.block.SPPF            [576, 576, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  2   1993728  ultralytics.nn.modules.block.C2f             [960, 384, 2]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  2    517632  ultralytics.nn.modules.block.C2f             [576, 192, 2]
#  16                  -1  1    332160  ultralytics.nn.modules.conv.Conv             [192, 192, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  2   1846272  ultralytics.nn.modules.block.C2f             [576, 384, 2]
#  19                  -1  1   1327872  ultralytics.nn.modules.conv.Conv             [384, 384, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  2   4207104  ultralytics.nn.modules.block.C2f             [960, 576, 2]
#  22        [15, 18, 21]  1   3822016  ultralytics.nn.modules.head.Detect           [80, [192, 384, 576]]
# YOLOv8m summary: 295 layers, 25902640 parameters, 25902624 gradients
#
# Transferred 475/475 items from pretrained weights

# %% [markdown]
# #### Access the webcam

# %%
def main():
    cap=cv2.VideoCapture(0)

    while True:
        ret,frame=cap.read()
        cv2.imshow("yolov8",frame)

        if(cv2.waitKey(30)==27):
            break
#if __name__=="__main__":
   # main()

# %% [markdown]
# #### Train the pre-trained model

# %%
# Train the model
results = model.train(data='data.yaml', epochs=5, imgsz=620)
# Out:
# New https://pypi.org/project/ultralytics/8.0.187 available  Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.180  Python-3.10.10 torch-2.0.1+cpu CPU (Intel Core(TM) i5-8250U 1.60GHz)
# engine\trainer: task=detect, mode=train, model=yolov8m.yaml, data=data.yaml, epochs=5, patience=50, batch=16, imgsz=620, save=True, save_period=-1, cache=False, device=None, workers=8, project=None, name=None, exist_ok=False, pretrained=True, optimizer=auto, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, amp=True, fraction=1.0, profile=False, freeze=None, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, show=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, vid_stride=1, stream_buffer=False, line_width=None, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, boxes=True, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=None, workspace=4, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, label_smoothing=0.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0, cfg=None, tracker=botsort.yaml, save_dir=runs\detect\train3
# Overriding model.yaml nc=80 with nc=1
#
#                    from  n    params  module                                       arguments
#   0                  -1  1      1392  ultralytics.nn.modules.conv.Conv             [3, 48, 3, 2]
#   1                  -1  1     41664  ultralytics.nn.modules.conv.Conv             [48, 96, 3, 2]
#   2                  -1  2    111360  ultralytics.nn.modules.block.C2f             [96, 96, 2, True]
#   3                  -1  1    166272  ultralytics.nn.modules.conv.Conv             [96, 192, 3, 2]
#   4                  -1  4    813312  ultralytics.nn.modules.block.C2f             [192, 192, 4, True]
#   5                  -1  1    664320  ultralytics.nn.modules.conv.Conv             [192, 384, 3, 2]
#   6                  -1  4   3248640  ultralytics.nn.modules.block.C2f             [384, 384, 4, True]
#   7                  -1  1   1991808  ultralytics.nn.modules.conv.Conv             [384, 576, 3, 2]
#   8                  -1  2   3985920  ultralytics.nn.modules.block.C2f             [576, 576, 2, True]
#   9                  -1  1    831168  ultralytics.nn.modules.block.SPPF            [576, 576, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  2   1993728  ultralytics.nn.modules.block.C2f             [960, 384, 2]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  2    517632  ultralytics.nn.modules.block.C2f             [576, 192, 2]
#  16                  -1  1    332160  ultralytics.nn.modules.conv.Conv             [192, 192, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  2   1846272  ultralytics.nn.modules.block.C2f             [576, 384, 2]
#  19                  -1  1   1327872  ultralytics.nn.modules.conv.Conv             [384, 384, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  2   4207104  ultralytics.nn.modules.block.C2f             [960, 576, 2]
#  22        [15, 18, 21]  1   3776275  ultralytics.nn.modules.head.Detect           [1, [192, 384, 576]]
# YOLOv8m summary: 295 layers, 25856899 parameters, 25856883 gradients
#
# Transferred 469/475 items from pretrained weights
# TensorBoard: Start with 'tensorboard --logdir runs\detect\train3', view at http://localhost:6006/
# Freezing layer 'model.22.dfl.conv.weight'
# WARNING  imgsz=[620] must be multiple of max stride 32, updating to [640]
# train: Scanning D:\repository\face_recognition\YOLOv8\data\train\labels... 0 images, 115 backgrounds, 0 corrupt: 100%|██████████| 115/115 [00:00<00:00, 368.44it/s]
# train: WARNING  No labels found in D:\repository\face_recognition\YOLOv8\data\train\labels.cache. See https://docs.ultralytics.com/datasets/detect for dataset formatting guidance.
# train: New cache created: D:\repository\face_recognition\YOLOv8\data\train\labels.cache
# WARNING  No labels found in D:\repository\face_recognition\YOLOv8\data\train\labels.cache, training may not work correctly. See https://docs.ultralytics.com/datasets/detect for dataset formatting guidance.
# val: Scanning D:\repository\face_recognition\YOLOv8\data\valid\labels.cache... 26 images, 13 backgrounds, 0 corrupt: 100%|██████████| 26/26 [00:00<?, ?it/s]
# Plotting labels to runs\detect\train3\labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.002, momentum=0.9) with parameter groups 77 weight(decay=0.0), 84 weight(decay=0.0005), 83 bias(decay=0.0)
# zero-size array to reduction operation maximum which has no identity
# Image sizes 640 train, 640 val
# Using 0 dataloader workers
# Logging results to runs\detect\train3
# Starting training for 5 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#         1/5         0G          0      215.5          0          0        640:  12%|█▎        | 1/8 [03:31<24:40, 211.56s/it]

# %% [markdown]
# #### Valid the model

# %%
#Load the trained model
model=YOLO('D:/repository/face_recognition/runs/detect/train2/weights/best.pt')  # load a custom model
# Validate the model
metrics = model.val()
# Out:
# Ultralytics YOLOv8.0.180  Python-3.10.10 torch-2.0.1+cpu CPU (Intel Core(TM) i5-8250U 1.60GHz)
# YOLOv8m summary (fused): 218 layers, 25840339 parameters, 0 gradients
# val: Scanning D:\repository\face_recognition\YOLOv8\data\valid\labels... 26 images, 13 backgrounds, 0 corrupt: 100%|██████████| 26/26 [00:00<00:00, 532.04it/s]
# val: New cache created: D:\repository\face_recognition\YOLOv8\data\valid\labels.cache
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:00<00:00,  2.51it/s]
#                    all         26         18      0.995      0.722      0.836      0.573
# Speed: 0.0ms preprocess, 18.3ms inference, 0.0ms loss, 0.7ms postprocess per image
# Results saved to runs\detect\val3

# %% [markdown]
# #### Predict the class on live real time data

# %%
#model.predict(source="0",show=True,conf=0.5)
# Out:
# 1/1: 0... Success  (inf frames of shape 640x480 at 30.00 FPS)
#
#
# WARNING  inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# 0: 32x32 (no detections), 33.9ms
# 0: 32x32 (no detections), 32.9ms
# 0: 32x32 (no detections), 27.9ms
# 0: 32x32 (no detections), 24.9ms
# 0: 32x32 (no detections), 27.9ms
# 0: 32x32 (no detections), 31.9ms
# 0: 32x32 (no detections), 25.9ms
# 0: 32x32 (no detections), 24.9ms
# 0: 32x32 (no detections), 24.9ms
# 0: 32x32 (no detections), 22.9ms
# 0: 32x32 (no detections), 24.9ms
# 0: 32x32 (no detections), 23.9ms
# 0: 32x32 (no detections), 25.9ms
# 0: 32x32 (no detections), 26.9ms
# 0: 32x32 (no detections), 23.9ms
# 0: 32x32 (no detections), 33.9ms
# 0: 32x32 (no detections), 21.9ms
# 0: 32x32 (no detections), 26.9ms
# 0: 32x32 (no detections), 21.9ms
# 0: 32x32 (no detections), 22.9ms
# 0: 32x32 (no detections), 26.9ms
# 0: 32x32 (no detections), 24.9ms
# 0: 32x32 (no detections), 20.9ms
# 0: 32x32 (no detections), 25.9ms
# 0: 32x32 (no detections), 30.9ms
# 0: 32x32 (no detections), 28.9ms
# 0: 32x32 (no detections), 32.9ms
# 0: 32x32 (no detections), 22.9ms
# 0: 32x32 (no detections), 28.9ms
# 0: 32x32 (no detections), 20.9ms
# 0: 32x32 (no detections), 21.9ms
# 0: 32x32 (no detections), 23.9ms
# 0: 32x32 (no detections), 25.9ms
# 0: 32x32 (no detections), 19.9ms
# 0: 32x32 (no detections), 17.0ms
# 0: 32x32 (no detections), 20.9ms
# 0: 32x32 (no detections), 21.9ms
# 0: 32x32 (no detections), 24.9ms
# 0: 32x32 (no detections), 21.9ms
# 0: 32x32 (no detections), 23.9ms
# 0: 32x32 (no detections), 23.9ms
# 0: 32x32 (no detections), 31.4ms
# 0: 32x32 (no detections), 21.9ms
# 0: 32x32 (no detections), 18.9ms
# 0: 32x32 (no detections), 18.0ms
# 0: 32x32 (no detections), 21.0ms
# 0: 32x32 (no detections), 121.9ms
# 0: 32x32 (no detections), 127.0ms
# 0: 32x32 (no detections), 73.0ms
# 0: 32x32 (no detections), 67.9ms
# 0: 32x32 (no detections), 58.6ms
# 0: 32x32 (no detections), 37.0ms
# 0: 32x32 (no detections), 28.5ms
# 0: 32x32 (no detections), 25.5ms
# 0: 32x32 (no detections), 25.1ms
# 0: 32x32 (no detections), 19.2ms
# 0: 32x32 (no detections), 26.9ms
# 0: 32x32 (no detections), 22.5ms
# 0: 32x32 (no detections), 21.0ms
# 0: 32x32 (no detections), 36.1ms
# 0: 32x32 (no detections), 33.0ms
# 0: 32x32 (no detections), 28.3ms
# 0: 32x32 (no detections), 22.8ms
# 0: 32x32 (no detections), 29.2ms
# 0: 32x32 (no detections), 24.5ms
# 0: 32x32 (no detections), 73.9ms
# 0: 32x32 (no detections), 177.4ms
# 0: 32x32 (no detections), 55.5ms
# 0: 32x32 (no detections), 28.9ms
# 0: 32x32 (no detections), 25.8ms
# 0: 32x32 (no detections), 21.0ms
# 0: 32x32 (no detections), 22.0ms
# 0: 32x32 (no detections), 24.1ms
# 0: 32x32 (no detections), 27.2ms
# 0: 32x32 (no detections), 22.7ms
# 0: 32x32 (no detections), 21.0ms
# 0: 32x32 (no detections), 32.4ms
# 0: 32x32 (no detections), 24.2ms
# 0: 32x32 (no detections), 27.0ms
# 0: 32x32 (no detections), 23.0ms
# 0: 32x32 (no detections), 24.9ms
# 0: 32x32 (no detections), 21.9ms
# 0: 32x32 (no detections), 34.6ms
# 0: 32x32 (no detections), 25.3ms
# 0: 32x32 (no detections), 30.6ms
# 0: 32x32 (no detections), 22.2ms
# 0: 32x32 (no detections), 38.7ms
# 0: 32x32 (no detections), 31.0ms
# 0: 32x32 (no detections), 22.2ms
# 0: 32x32 (no detections), 32.0ms
# 0: 32x32 (no detections), 30.7ms
# 0: 32x32 (no detections), 20.9ms
# 0: 32x32 (no detections), 27.2ms
# 0: 32x32 (no detections), 24.0ms
# 0: 32x32 (no detections), 21.0ms
# 0: 32x32 (no detections), 21.9ms
# 0: 32x32 (no detections), 26.4ms
# 0: 32x32 (no detections), 23.1ms
# 0: 32x32 (no detections), 24.3ms
# 0: 32x32 (no detections), 30.7ms
# 0: 32x32 (no detections), 23.0ms
# 0: 32x32 (no detections), 22.3ms
# 0: 32x32 (no detections), 27.9ms
# 0: 32x32 (no detections), 25.0ms
# 0: 32x32 (no detections), 22.8ms
# 0: 32x32 (no detections), 22.9ms
# 0: 32x32 (no detections), 26.6ms
# 0: 32x32 (no detections), 21.5ms
# 0: 32x32 (no detections), 23.0ms
# 0: 32x32 (no detections), 40.1ms
# 0: 32x32 (no detections), 30.0ms
# 0: 32x32 (no detections), 28.9ms
# 0: 32x32 (no detections), 26.0ms
# 0: 32x32 (no detections), 25.7ms
# 0: 32x32 (no detections), 20.3ms
# 0: 32x32 (no detections), 22.4ms
# 0: 32x32 (no detections), 25.0ms
# 0: 32x32 (no detections), 20.8ms
# 0: 32x32 (no detections), 26.2ms
# 0: 32x32 (no detections), 89.7ms
# 0: 32x32 (no detections), 28.7ms
# 0: 32x32 (no detections), 28.6ms
# 0: 32x32 (no detections), 25.1ms
# 0: 32x32 (no detections), 26.9ms
# 0: 32x32 (no detections), 33.5ms
# 0: 32x32 (no detections), 37.6ms
# 0: 32x32 (no detections), 25.9ms
# 0: 32x32 (no detections), 26.3ms
# 0: 32x32 (no detections), 20.1ms
# 0: 32x32 (no detections), 24.2ms
# 0: 32x32 (no detections), 22.0ms
# 0: 32x32 (no detections), 24.9ms
# 0: 32x32 (no detections), 32.4ms
# 0: 32x32 (no detections), 23.3ms
# 0: 32x32 (no detections), 25.0ms
# 0: 32x32 (no detections), 22.9ms
# 0: 32x32 (no detections), 21.6ms
# 0: 32x32 (no detections), 18.6ms
# 0: 32x32 (no detections), 29.3ms
# 0: 32x32 (no detections), 41.0ms
# 0: 32x32 (no detections), 31.2ms
# 0: 32x32 (no detections), 22.8ms
# 0: 32x32 (no detections), 25.7ms
# 0: 32x32 (no detections), 28.4ms
# 0: 32x32 (no detections), 30.9ms
# 0: 32x32 (no detections), 27.2ms
# 0: 32x32 (no detections), 22.9ms
# 0: 32x32 (no detections), 19.9ms
# 0: 32x32 (no detections), 18.0ms
# 0: 32x32 (no detections), 22.7ms
# 0: 32x32 (no detections), 23.9ms
# 0: 32x32 (no detections), 26.4ms
# 0: 32x32 (no detections), 29.0ms
# 0: 32x32 (no detections), 21.2ms
# 0: 32x32 (no detections), 17.0ms
# 0: 32x32 (no detections), 20.9ms
# 0: 32x32 (no detections), 21.1ms
# 0: 32x32 (no detections), 31.9ms
# 0: 32x32 (no detections), 24.1ms
# 0: 32x32 (no detections), 29.1ms
# 0: 32x32 (no detections), 21.7ms
# 0: 32x32 (no detections), 21.3ms
# 0: 32x32 (no detections), 26.0ms
# 0: 32x32 (no detections), 26.6ms
# 0: 32x32 (no detections), 29.9ms
# 0: 32x32 (no detections), 28.5ms
# 0: 32x32 (no detections), 25.5ms
# 0: 32x32 (no detections), 21.7ms
# 0: 32x32 (no detections), 19.9ms
# 0: 32x32 (no detections), 26.0ms
# 0: 32x32 (no detections), 20.7ms
# 0: 32x32 (no detections), 25.1ms
# 0: 32x32 (no detections), 30.0ms
# 0: 32x32 (no detections), 27.9ms
# 0: 32x32 (no detections), 31.9ms
# 0: 32x32 (no detections), 20.4ms
# 0: 32x32 (no detections), 23.4ms
# 0: 32x32 (no detections), 21.5ms
# 0: 32x32 (no detections), 26.4ms
# 0: 32x32 (no detections), 21.5ms
# 0: 32x32 (no detections), 17.0ms
# 0: 32x32 (no detections), 28.4ms
# 0: 32x32 (no detections), 26.9ms
# 0: 32x32 (no detections), 25.9ms
# 0: 32x32 (no detections), 27.3ms
# 0: 32x32 (no detections), 21.9ms
# 0: 32x32 (no detections), 24.0ms
# 0: 32x32 (no detections), 22.1ms
# 0: 32x32 (no detections), 25.7ms
# 0: 32x32 (no detections), 24.1ms
# 0: 32x32 (no detections), 21.0ms
# 0: 32x32 (no detections), 26.0ms
# 0: 32x32 (no detections), 29.3ms
# 0: 32x32 (no detections), 28.0ms
# 0: 32x32 (no detections), 27.2ms
# 0: 32x32 (no detections), 25.4ms
# 0: 32x32 (no detections), 23.2ms
# 0: 32x32 (no detections), 20.1ms
# 0: 32x32 (no detections), 15.8ms
# 0: 32x32 (no detections), 23.0ms
# 0: 32x32 (no detections), 23.9ms
# 0: 32x32 (no detections), 24.2ms
# 0: 32x32 (no detections), 26.8ms
# 0: 32x32 (no detections), 28.6ms
# 0: 32x32 (no detections), 35.7ms
# 0: 32x32 (no detections), 37.9ms
# 0: 32x32 (no detections), 29.2ms
# 0: 32x32 (no detections), 17.3ms
# 0: 32x32 (no detections), 22.9ms
# 0: 32x32 (no detections), 21.0ms
# 0: 32x32 (no detections), 19.3ms
# 0: 32x32 (no detections), 18.0ms
# 0: 32x32 (no detections), 19.4ms
# 0: 32x32 (no detections), 27.4ms
# 0: 32x32 (no detections), 24.1ms
# 0: 32x32 (no detections), 17.0ms
# 0: 32x32 (no detections), 19.0ms
# 0: 32x32 (no detections), 17.1ms
# 0: 32x32 (no detections), 16.9ms
# 0: 32x32 (no detections), 32.9ms
# 0: 32x32 (no detections), 25.0ms
# 0: 32x32 (no detections), 26.9ms
# 0: 32x32 (no detections), 23.9ms
# 0: 32x32 (no detections), 18.9ms
# 0: 32x32 (no detections), 23.0ms
# 0: 32x32 (no detections), 18.0ms
# 0: 32x32 (no detections), 21.6ms
# 0: 32x32 (no detections), 23.9ms
# 0: 32x32 (no detections), 26.0ms
# 0: 32x32 (no detections), 23.5ms
# 0: 32x32 (no detections), 16.0ms
# 0: 32x32 (no detections), 18.0ms
# 0: 32x32 (no detections), 18.3ms
# 0: 32x32 (no detections), 25.9ms
# 0: 32x32 (no detections), 28.0ms
# 0: 32x32 (no detections), 26.0ms
# 0: 32x32 (no detections), 25.9ms
# 0: 32x32 (no detections), 27.2ms
# 0: 32x32 (no detections), 22.1ms
# 0: 32x32 (no detections), 22.3ms
# 0: 32x32 (no detections), 32.0ms
# 0: 32x32 (no detections), 20.2ms
# 0: 32x32 (no detections), 16.1ms
# 0: 32x32 (no detections), 19.0ms
# 0: 32x32 (no detections), 15.0ms
# 0: 32x32 (no detections), 23.7ms
# 0: 32x32 (no detections), 23.9ms
# 0: 32x32 (no detections), 22.0ms
# 0: 32x32 (no detections), 19.5ms
# 0: 32x32 (no detections), 18.2ms
# 0: 32x32 (no detections), 18.8ms
# 0: 32x32 (no detections), 25.9ms
# 0: 32x32 (no detections), 26.9ms
# 0: 32x32 (no detections), 26.9ms
# 0: 32x32 (no detections), 26.9ms
# 0: 32x32 (no detections), 17.3ms
# 0: 32x32 (no detections), 18.5ms
# 0: 32x32 (no detections), 24.7ms
# 0: 32x32 (no detections), 19.0ms
# 0: 32x32 (no detections), 26.4ms
# 0: 32x32 (no detections), 27.0ms
# 0: 32x32 (no detections), 30.3ms
# 0: 32x32 (no detections), 25.0ms
# 0: 32x32 (no detections), 28.9ms
# 0: 32x32 (no detections), 21.0ms
# 0: 32x32 (no detections), 17.9ms
# 0: 32x32 (no detections), 18.9ms
# 0: 32x32 (no detections), 16.0ms
# 0: 32x32 (no detections), 27.0ms
# 0: 32x32 (no detections), 26.2ms
# 0: 32x32 (no detections), 26.5ms
# 0: 32x32 (no detections), 29.9ms
# 0: 32x32 (no detections), 18.9ms
# 0: 32x32 (no detections), 19.9ms
# 0: 32x32 (no detections), 19.4ms
# 0: 32x32 (no detections), 16.9ms
# 0: 32x32 (no detections), 15.0ms
# 0: 32x32 (no detections), 25.0ms
# 0: 32x32 (no detections), 21.7ms
# 0: 32x32 (no detections), 63.3ms
# 0: 32x32 (no detections), 23.9ms
# 0: 32x32 (no detections), 26.9ms
# 0: 32x32 (no detections), 26.7ms
# 0: 32x32 (no detections), 21.2ms
# 0: 32x32 (no detections), 29.9ms
# 0: 32x32 (no detections), 27.9ms
# 0: 32x32 (no detections), 25.0ms
# 0: 32x32 (no detections), 22.9ms
# 0: 32x32 (no detections), 20.3ms
# 0: 32x32 (no detections), 18.9ms
# 0: 32x32 (no detections), 23.0ms
# 0: 32x32 (no detections), 23.7ms
# 0: 32x32 (no detections), 23.1ms
# 0: 32x32 (no detections), 19.8ms
# 0: 32x32 (no detections), 20.4ms
# 0: 32x32 (no detections), 19.5ms
# 0: 32x32 (no detections), 20.7ms
# 0: 32x32 (no detections), 20.9ms
# 0: 32x32 (no detections), 24.4ms
# 0: 32x32 (no detections), 22.0ms
# 0: 32x32 (no detections), 18.5ms
# 0: 32x32 (no detections), 18.2ms
# 0: 32x32 (no detections), 18.9ms
# 0: 32x32 (no detections), 21.3ms
# 0: 32x32 (no detections), 19.6ms
# 0: 32x32 (no detections), 25.0ms
# 0: 32x32 (no detections), 20.3ms
# 0: 32x32 (no detections), 24.9ms
# 0: 32x32 (no detections), 26.9ms
# 0: 32x32 (no detections), 29.0ms
# 0: 32x32 (no detections), 20.2ms
# 0: 32x32 (no detections), 22.2ms
# 0: 32x32 (no detections), 21.9ms
# 0: 32x32 (no detections), 18.9ms
# 0: 32x32 (no detections), 24.0ms
# 0: 32x32 (no detections), 24.9ms
# 0: 32x32 (no detections), 22.7ms
# 0: 32x32 (no detections), 25.3ms
# 0: 32x32 (no detections), 24.0ms
# 0: 32x32 (no detections), 20.9ms
# 0: 32x32 (no detections), 16.9ms
# 0: 32x32 (no detections), 16.5ms
# 0: 32x32 (no detections), 23.0ms
# 0: 32x32 (no detections), 18.8ms
# 0: 32x32 (no detections), 23.8ms
# 0: 32x32 (no detections), 22.9ms
# 0: 32x32 (no detections), 23.1ms
# 0: 32x32 (no detections), 21.8ms
# 0: 32x32 (no detections), 18.6ms
# 0: 32x32 (no detections), 16.9ms
# 0: 32x32 (no detections), 25.0ms
# 0: 32x32 (no detections), 23.9ms
# 0: 32x32 (no detections), 29.2ms
# 0: 32x32 (no detections), 26.9ms
# 0: 32x32 (no detections), 21.1ms
# 0: 32x32 (no detections), 19.3ms
# 0: 32x32 (no detections), 19.7ms
# 0: 32x32 (no detections), 23.4ms
# 0: 32x32 (no detections), 25.5ms
# 0: 32x32 (no detections), 24.9ms
# 0: 32x32 (no detections), 27.1ms
# 0: 32x32 (no detections), 34.7ms
# 0: 32x32 (no detections), 24.0ms
# 0: 32x32 (no detections), 25.3ms
# 0: 32x32 (no detections), 18.0ms
# 0: 32x32 (no detections), 19.1ms
# 0: 32x32 (no detections), 18.7ms
# 0: 32x32 (no detections), 19.1ms
# 0: 32x32 (no detections), 18.9ms
# 0: 32x32 (no detections), 22.2ms
# 0: 32x32 (no detections), 18.7ms
# 0: 32x32 (no detections), 18.1ms
# 0: 32x32 (no detections), 23.4ms
# 0: 32x32 (no detections), 21.9ms
# 0: 32x32 (no detections), 29.9ms
# 0: 32x32 (no detections), 36.0ms
# 0: 32x32 (no detections), 41.9ms
# 0: 32x32 (no detections), 32.5ms
# 0: 32x32 (no detections), 26.9ms
# 0: 32x32 (no detections), 19.7ms
# 0: 32x32 (no detections), 16.9ms
# 0: 32x32 (no detections), 21.3ms
# 0: 32x32 (no detections), 18.8ms
# 0: 32x32 (no detections), 22.7ms
# 0: 32x32 (no detections), 24.8ms
# 0: 32x32 (no detections), 24.0ms
# 0: 32x32 (no detections), 22.4ms
# 0: 32x32 (no detections), 19.9ms
# 0: 32x32 (no detections), 20.1ms
# 0: 32x32 (no detections), 17.0ms
# 0: 32x32 (no detections), 20.4ms
# 0: 32x32 (no detections), 18.9ms
# 0: 32x32 (no detections), 17.5ms
# 0: 32x32 (no detections), 22.8ms
# 0: 32x32 (no detections), 24.9ms
# 0: 32x32 (no detections), 25.9ms
# 0: 32x32 (no detections), 24.0ms
# 0: 32x32 (no detections), 17.9ms
# 0: 32x32 (no detections), 17.0ms
# 0: 32x32 (no detections), 22.6ms
# 0: 32x32 (no detections), 31.3ms
# 0: 32x32 (no detections), 24.8ms
# 0: 32x32 (no detections), 26.9ms
# 0: 32x32 (no detections), 23.3ms
# 0: 32x32 (no detections), 20.8ms
# 0: 32x32 (no detections), 18.9ms
# 0: 32x32 (no detections), 20.4ms
# 0: 32x32 (no detections), 17.2ms
# 0: 32x32 (no detections), 13.0ms
# 0: 32x32 (no detections), 20.9ms
# 0: 32x32 (no detections), 17.2ms
# 0: 32x32 (no detections), 17.4ms
# 0: 32x32 (no detections), 18.0ms
# 0: 32x32 (no detections), 19.8ms
# 0: 32x32 (no detections), 17.1ms
# 0: 32x32 (no detections), 20.2ms
# 0: 32x32 (no detections), 17.5ms
# 0: 32x32 (no detections), 17.7ms
# 0: 32x32 (no detections), 22.0ms
# 0: 32x32 (no detections), 20.2ms
# 0: 32x32 (no detections), 20.2ms
# 0: 32x32 (no detections), 21.5ms
# 0: 32x32 (no detections), 21.3ms
# 0: 32x32 (no detections), 21.0ms
# 0: 32x32 (no detections), 21.9ms
# 0: 32x32 (no detections), 21.9ms
# 0: 32x32 (no detections), 26.5ms
# 0: 32x32 (no detections), 18.9ms
# 0: 32x32 (no detections), 22.9ms
# 0: 32x32 (no detections), 23.9ms
# 0: 32x32 (no detections), 30.9ms
# 0: 32x32 (no detections), 28.9ms
# 0: 32x32 (no detections), 22.9ms
# 0: 32x32 (no detections), 20.1ms
# 0: 32x32 (no detections), 24.0ms
# 0: 32x32 (no detections), 21.0ms
# 0: 32x32 (no detections), 21.9ms
# 0: 32x32 (no detections), 20.8ms
# 0: 32x32 (no detections), 21.0ms
# 0: 32x32 (no detections), 21.9ms
# 0: 32x32 (no detections), 36.6ms
# 0: 32x32 (no detections), 21.1ms
# 0: 32x32 (no detections), 21.8ms
# 0: 32x32 (no detections), 22.9ms
# 0: 32x32 (no detections), 19.5ms
# 0: 32x32 (no detections), 17.0ms
# 0: 32x32 (no detections), 20.0ms
# 0: 32x32 (no detections), 20.5ms
# 0: 32x32 (no detections), 17.5ms
# 0: 32x32 (no detections), 18.5ms
# 0: 32x32 (no detections), 20.0ms
# 0: 32x32 (no detections), 19.3ms
# 0: 32x32 (no detections), 20.8ms
# 0: 32x32 (no detections), 19.5ms
# 0: 32x32 (no detections), 40.5ms
# 0: 32x32 (no detections), 62.1ms
# 0: 32x32 (no detections), 19.0ms
# 0: 32x32 (no detections), 18.4ms
# 0: 32x32 1 face, 26.9ms
# 0: 32x32 1 face, 25.9ms
# 0: 32x32 1 face, 17.6ms
# 0: 32x32 (no detections), 19.1ms
# 0: 32x32 (no detections), 19.9ms
# 0: 32x32 1 face, 23.1ms
# 0: 32x32 1 face, 23.0ms
# 0: 32x32 (no detections), 19.5ms
# 0: 32x32 (no detections), 18.4ms
# 0: 32x32 (no detections), 16.8ms
# 0: 32x32 (no detections), 18.8ms
# 0: 32x32 (no detections), 26.1ms
# 0: 32x32 (no detections), 22.7ms
# 0: 32x32 (no detections), 30.9ms
# 0: 32x32 (no detections), 20.6ms
# 0: 32x32 (no detections), 22.2ms
# 0: 32x32 1 face, 18.9ms
# 0: 32x32 1 face, 18.1ms
# 0: 32x32 1 face, 15.0ms
# 0: 32x32 1 face, 16.8ms
# 0: 32x32 1 face, 18.9ms
# 0: 32x32 1 face, 16.2ms
# 0: 32x32 1 face, 21.0ms
# 0: 32x32 1 face, 22.0ms
# 0: 32x32 1 face, 24.0ms
# 0: 32x32 1 face, 23.9ms
# 0: 32x32 1 face, 22.1ms
# 0: 32x32 1 face, 27.9ms
# 0: 32x32 1 face, 26.0ms
# 0: 32x32 (no detections), 26.9ms
# 0: 32x32
9ms
# 0: 32x32 (no detections), 25.9ms
# 0: 32x32 (no detections), 25.9ms
# 0: 32x32 (no detections), 20.3ms
# 0: 32x32 (no detections), 22.1ms
# 0: 32x32 (no detections), 23.0ms
# 0: 32x32 (no detections), 24.0ms
# 0: 32x32 (no detections), 28.9ms
# 0: 32x32 (no detections), 24.0ms
# 0: 32x32 (no detections), 21.5ms
# 0: 32x32 (no detections), 22.2ms
# 0: 32x32 (no detections), 19.6ms
# 0: 32x32 (no detections), 21.2ms
# 0: 32x32 (no detections), 22.0ms
# 0: 32x32 (no detections), 39.4ms
# 0: 32x32 (no detections), 28.0ms
# 0: 32x32 (no detections), 33.5ms
# 0: 32x32 (no detections), 20.7ms
# 0: 32x32 (no detections), 23.7ms
# 0: 32x32 (no detections), 21.5ms
# 0: 32x32 (no detections), 27.4ms
# 0: 32x32 (no detections), 22.9ms
# 0: 32x32 (no detections), 22.7ms
# 0: 32x32 (no detections), 25.7ms
# 0: 32x32 (no detections), 22.0ms
# 0: 32x32 (no detections), 20.6ms
# 0: 32x32 (no detections), 19.6ms
# 0: 32x32 1 face, 21.5ms
# 0: 32x32 (no detections), 22.1ms
# 0: 32x32 (no detections), 22.8ms
# 0: 32x32 (no detections), 19.0ms
# 0: 32x32 (no detections), 25.6ms
# 0: 32x32 (no detections), 35.8ms
# 0: 32x32 (no detections), 34.3ms
# 0: 32x32 (no detections), 27.2ms
# 0: 32x32 (no detections), 22.7ms
# 0: 32x32 (no detections), 21.3ms
# 0: 32x32 (no detections), 26.8ms
# 0: 32x32 (no detections), 36.9ms
# 0: 32x32 (no detections), 39.9ms
# 0: 32x32 (no detections), 46.0ms
# 0: 32x32 (no detections), 35.1ms
# 0: 32x32 (no detections), 21.0ms
# 0: 32x32 (no detections), 24.6ms
# 0: 32x32 (no detections), 24.4ms
# 0: 32x32 (no detections), 22.5ms
# 0: 32x32 (no detections), 22.8ms
# 0: 32x32 (no detections), 18.0ms
# 0: 32x32 (no detections), 24.8ms
# 0: 32x32 (no detections), 27.9ms
# 0: 32x32 (no detections), 28.9ms
# 0: 32x32 (no detections), 25.0ms
# 0: 32x32 (no detections), 30.2ms
# 0: 32x32 (no detections), 23.1ms
# 0: 32x32 (no detections), 19.0ms
# 0: 32x32 (no detections), 25.6ms
# 0: 32x32 (no detections), 18.0ms
# 0: 32x32 (no detections), 18.8ms
# 0: 32x32 (no detections), 21.1ms
# 0: 32x32 (no detections), 17.8ms
# 0: 32x32 (no detections), 35.4ms
# 0: 32x32 (no detections), 21.9ms
# 0: 32x32 (no detections), 24.6ms
# 0: 32x32 (no detections), 21.7ms
# 0: 32x32 (no detections), 23.5ms
# 0: 32x32 (no detections), 22.5ms
# 0: 32x32 (no detections), 22.1ms
# 0: 32x32 (no detections), 18.8ms
# 0: 32x32 (no detections), 20.0ms
# 0: 32x32 (no detections), 24.1ms
# 0: 32x32 (no detections), 23.0ms
# 0: 32x32 (no detections), 30.0ms
# 0: 32x32 (no detections), 30.1ms
# 0: 32x32 (no detections), 32.1ms
# 0: 32x32 (no detections), 19.9ms
# 0: 32x32 (no detections), 21.5ms
# 0: 32x32 (no detections), 26.4ms
# 0: 32x32 (no detections), 22.5ms
# 0: 32x32 (no detections), 23.2ms
# 0: 32x32 (no detections), 21.9ms
# 0: 32x32 (no detections), 25.6ms
# 0: 32x32 (no detections), 22.5ms
# 0: 32x32 (no detections), 24.9ms
# 0: 32x32 (no detections), 23.3ms
# 0: 32x32 (no detections), 23.1ms
# 0: 32x32 (no detections), 26.3ms
# 0: 32x32 (no detections), 17.8ms
# 0: 32x32 (no detections), 22.9ms
# 0: 32x32 (no detections), 34.4ms
# 0: 32x32 (no detections), 26.8ms
# 0: 32x32 (no detections), 27.2ms
# 0: 32x32 (no detections), 21.9ms
# 0: 32x32 (no detections), 32.1ms
# 0: 32x32 (no detections), 28.5ms
# 0: 32x32 (no detections), 27.9ms
# 0: 32x32 (no detections), 32.3ms
# 0: 32x32 (no detections), 26.1ms
# 0: 32x32 (no detections), 24.8ms
# 0: 32x32 (no detections), 236.6ms
# 0: 32x32 (no detections), 33.2ms
# 0: 32x32 (no detections), 67.0ms
# 0: 32x32 (no detections), 34.9ms
# 0: 32x32 (no detections), 29.6ms
# 0: 32x32 (no detections), 32.9ms
# 0: 32x32 (no detections), 22.3ms
# 0: 32x32 (no detections), 36.7ms
# 0: 32x32 (no detections), 48.0ms
# 0: 32x32 (no detections), 67.2ms
# 0: 32x32 (no detections), 35.9ms
# 0: 32x32 (no detections), 32.0ms
# 0: 32x32 (no detections), 34.4ms
# 0: 32x32 (no detections), 112.8ms
# 0: 32x32 (no detections), 23.9ms
# 0: 32x32 (no detections), 26.5ms
# 0: 32x32 (no detections), 24.5ms
# 0: 32x32 (no detections), 28.5ms
# 0: 32x32 (no detections), 39.5ms
# 0: 32x32 (no detections), 38.9ms
# 0: 32x32 (no detections), 33.9ms
# 0: 32x32 (no detections), 26.2ms
# 0: 32x32 1 face, 22.0ms
# 0: 32x32 (no detections), 22.0ms
# 0: 32x32 (no detections), 24.1ms
# 0: 32x32 (no detections), 19.9ms
# 0: 32x32 (no detections), 23.4ms
# 0: 32x32 1 face, 56.1ms
# 0: 32x32 1 face, 49.9ms
# 0: 32x32 1 face, 29.1ms
# 0: 32x32 1 face, 38.7ms
# 0: 32x32 1 face, 91.1ms
# 0: 32x32 1 face, 45.4ms
# 0: 32x32 1 face, 23.2ms
# 0: 32x32 1 face, 28.2ms
# 0: 32x32 1 face, 30.7ms
# 0: 32x32 (no detections), 29.0ms
# 0: 32x32 (no detections), 22.0ms
# 0: 32x32 1 face, 27.6ms
# 0: 32x32 1 face, 29.4ms
# 0: 32x32 1 face, 23.0ms
# 0: 32x32 (no detections), 25.4ms
# 0: 32x32 (no detections), 25.8ms
# 0: 32x32 (no detections), 25.2ms
# 0: 32x32 (no detections), 34.8ms
# 0: 32x32 (no detections), 35.2ms
# 0: 32x32 (no detections), 30.9ms
# 0: 32x32 (no detections),
ms
# 0: 32x32 (no detections), 24.0ms
# 0: 32x32 1 face, 20.8ms
# 0: 32x32 1 face, 19.9ms
# 0: 32x32 1 face, 20.9ms
# 0: 32x32 1 face, 26.5ms
# 0: 32x32 1 face, 23.9ms
# 0: 32x32 1 face, 28.6ms
# 0: 32x32 1 face, 27.3ms
# 0: 32x32 1 face, 31.1ms
# 0: 32x32 1 face, 30.1ms
# 0: 32x32 1 face, 22.4ms
# 0: 32x32 1 face, 21.9ms
# 0: 32x32 1 face, 25.6ms
# 0: 32x32 1 face, 21.0ms
# 0: 32x32 1 face, 24.4ms
# 0: 32x32 1 face, 27.5ms
# 0: 32x32 1 face, 43.3ms
# 0: 32x32 1 face, 31.2ms
# 0: 32x32 1 face, 31.7ms
# 0: 32x32 1 face, 21.9ms
# 0: 32x32 1 face, 26.7ms
# 0: 32x32 (no detections), 32.2ms
# 0: 32x32 (no detections), 51.0ms
# 0: 32x32 (no detections), 24.8ms
# 0: 32x32 1 face, 25.9ms
# 0: 32x32 1 face, 27.1ms
# 0: 32x32 1 face, 36.1ms
# 0: 32x32 1 face, 33.7ms
# 0: 32x32 1 face, 31.9ms
# 0: 32x32 1 face, 30.9ms
# 0: 32x32 1 face, 19.8ms
# 0: 32x32 1 face, 22.4ms
# 0: 32x32 (no detections), 24.0ms
# 0: 32x32 (no detections), 71.2ms
# 0: 32x32 (no detections), 26.0ms
# 0: 32x32 (no detections), 24.1ms
# 0: 32x32 (no detections), 21.0ms
# 0: 32x32 (no detections), 25.6ms
# 0: 32x32 (no detections), 26.2ms
# 0: 32x32 1 face, 21.9ms
# 0: 32x32 1 face, 23.1ms
# 0: 32x32 1 face, 19.9ms
# 0: 32x32 1 face, 27.9ms
# 0: 32x32 1 face, 29.2ms
# 0: 32x32 1 face, 34.9ms
# 0: 32x32 1 face, 31.1ms
# 0: 32x32 (no detections), 27.2ms
# 0: 32x32 (no detections), 24.8ms
# 0: 32x32 (no detections), 25.8ms
# 0: 32x32 (no detections), 19.0ms
# 0: 32x32 (no detections), 23.9ms
# 0: 32x32 (no detections), 20.6ms
# 0: 32x32 (no detections), 23.8ms
# 0: 32x32 (no detections), 25.0ms
# 0: 32x32 (no detections), 24.3ms
# 0: 32x32 (no detections), 18.0ms
# 0: 32x32 (no detections), 20.6ms
# 0: 32x32 (no detections), 24.0ms
# 0: 32x32 (no detections), 27.7ms
# 0: 32x32 (no detections), 27.9ms
# 0: 32x32 (no detections), 30.1ms
# 0: 32x32 (no detections), 25.1ms
# 0: 32x32 (no detections), 19.9ms
# 0: 32x32 (no detections), 21.9ms
# 0: 32x32 (no detections), 20.2ms
# 0: 32x32 (no detections), 21.9ms
# 0: 32x32 (no detections), 24.0ms
# 0: 32x32 (no detections), 25.2ms
# 0: 32x32 (no detections), 20.0ms
# 0: 32x32 (no detections), 21.2ms
# 0: 32x32 (no detections), 20.4ms
# 0: 32x32 (no detections), 21.7ms
# 0: 32x32 (no detections), 24.0ms
# 0: 32x32 (no detections), 20.2ms
# 0: 32x32 (no detections), 26.9ms
# 0: 32x32 (no detections), 27.6ms
# 0: 32x32 (no detections), 33.9ms
# 0: 32x32 (no detections), 29.4ms
# 0: 32x32 (no detections), 22.9ms
# 0: 32x32 (no detections), 25.0ms
# 0: 32x32 (no detections), 22.2ms
# 0: 32x32 (no detections), 18.0ms
# 0: 32x32 (no detections), 25.0ms
# 0: 32x32 (no detections), 35.0ms
# 0: 32x32 (no detections), 20.2ms
# 0: 32x32 (no detections), 23.8ms
# 0: 32x32 (no detections), 24.9ms
# 0: 32x32 (no detections), 20.2ms
# 0: 32x32 (no detections), 20.9ms
# 0: 32x32 (no detections), 22.0ms
# 0: 32x32 (no detections), 22.9ms
# 0: 32x32 (no detections), 28.5ms
# 0: 32x32 (no detections), 43.9ms
# 0: 32x32 (no detections), 38.9ms
# 0: 32x32 (no detections), 37.9ms
# 0: 32x32 (no detections), 39.9ms
# 0: 32x32 (no detections), 18.9ms
# 0: 32x32 (no detections), 24.8ms
# 0: 32x32 (no detections), 20.7ms
# 0: 32x32 (no detections), 21.5ms
# 0: 32x32 (no detections), 19.0ms
# 0: 32x32 (no detections), 20.4ms
# 0: 32x32 (no detections), 21.1ms
# 0: 32x32 (no detections), 24.6ms
# 0: 32x32 (no detections), 19.9ms
# 0: 32x32 (no detections), 20.0ms
# 0: 32x32 (no detections), 21.6ms
# 0: 32x32 (no detections), 23.1ms
# 0: 32x32 (no detections), 22.9ms
# 0: 32x32 (no detections), 30.0ms
# 0: 32x32 (no detections), 29.2ms
# 0: 32x32 (no detections), 28.9ms
# 0: 32x32 (no detections), 22.8ms
# 0: 32x32 (no detections), 18.7ms
# 0: 32x32 (no detections), 22.9ms
# 0: 32x32 (no detections), 22.9ms
# 0: 32x32 (no detections), 18.3ms
# 0: 32x32 (no detections), 20.9ms
# 0: 32x32 (no detections), 20.9ms
# 0: 32x32 (no detections), 23.2ms
# 0: 32x32 (no detections), 18.4ms
# 0: 32x32 (no detections), 19.5ms
# 0: 32x32 (no detections), 18.8ms
# 0: 32x32 (no detections), 22.0ms
# 0: 32x32 (no detections), 30.5ms
# 0: 32x32 (no detections), 37.0ms
# 0: 32x32 (no detections), 27.0ms
# 0: 32x32 (no detections), 22.7ms
# 0: 32x32 (no detections), 25.1ms
# 0: 32x32 (no detections), 31.1ms
# 0: 32x32 (no detections), 31.6ms
# 0: 32x32 (no detections), 35.0ms
# 0: 32x32 (no detections), 65.0ms
# 0: 32x32 (no detections), 40.5ms
# 0: 32x32 (no detections), 44.9ms
# 0: 32x32 (no detections), 28.1ms
# 0: 32x32 (no detections), 50.9ms
# 0: 32x32 (no detections), 31.1ms
# 0: 32x32 (no detections), 36.5ms
# 0: 32x32 (no detections), 34.0ms
# 0: 32x32 (no detections), 40.5ms
# 0: 32x32 (no detections), 52.2ms
# 0: 32x32 (no detections), 36.2ms
# 0: 32x32 (no detections), 28.1ms
# 0: 32x32 (no detections), 19.7ms
# 0: 32x32 (no detections), 20.0ms
# 0: 32x32 (no detections), 23.5ms
# 0: 32x32 (no detections), 23.0ms
# 0: 32x32 (no detections), 23.1ms
# 0: 32x32 (no detections), 23.8ms
# 0: 32x32 (no detections), 24.0ms
# 0: 32x32 (no detections), 20.4ms
# 0: 32x32 (no detections), 19.8ms
# 0: 32x32 (no detections), 22.0ms
# 0: 32x32 (no detections), 18.0ms
# 0: 32x32 (no detections), 19.3ms
# 0: 32x32 (no detections), 21.8ms
# 0: 32x32 (no detections), 20.9ms
# 0: 32x32 (no detections), 19.5ms
# 0: 32x32 (no detections), 24.9ms
# 0: 32x32 (no detections), 20.3ms
# 0: 32x32 (no detections), 19.9ms
# 0: 32x32 (no detections), 28.9ms
# 0: 32x32 (no detections), 29.5ms
# 0: 32x32 (no detections), 29.3ms
# 0: 32x32 (no detections), 28.6ms
# 0: 32x32 (no detections), 25.9ms
# 0: 32x32 (no detections), 24.8ms
# 0: 32x32 (no detections), 16.5ms
# 0: 32x32 (no detections), 19.8ms
# 0: 32x32 (no detections), 31.3ms
# 0: 32x32 (no detections), 21.0ms
# 0: 32x32 (no detections), 20.3ms
# 0: 32x32 (no detections), 23.8ms
# 0: 32x32 (no detections), 26.1ms
# 0: 32x32 (no detections), 20.9ms
# 0: 32x32 (no detections), 21.4ms
# 0: 32x32 (no detections), 17.1ms
# 0: 32x32 (no detections), 23.7ms
# 0: 32x32 (no detections), 19.3ms
# 0: 32x32 (no detections), 24.0ms
# 0: 32x32 (no detections), 19.9ms
# 0: 32x32 (no detections), 19.5ms
# 0: 32x32 (no detections), 20.4ms
# 0: 32x32 (no detections), 21.5ms
# 0: 32x32 (no detections), 91.7ms
# 0: 32x32 (no detections), 35.5ms
# 0: 32x32 (no detections), 29.9ms
# 0: 32x32 (no detections), 18.9ms
# 0: 32x32 (no detections), 21.9ms
# 0: 32x32 (no detections), 25.3ms
# 0: 32x32 (no detections), 19.6ms
# 0: 32x32 (no detections), 20.3ms
# 0: 32x32 (no detections), 19.5ms
# 0: 32x32 (no detections), 18.2ms
# 0: 32x32 (no detections), 19.0ms
# 0: 32x32 (no detections), 18.0ms
# 0: 32x32 (no detections), 22.3ms
# 0: 32x32 (no detections), 20.3ms
# 0: 32x32 (no detections), 25.7ms
# 0: 32x32 (no detections), 25.6ms
# 0: 32x32 (no detections), 28.5ms
# 0: 32x32 (no detections), 23.8ms
# 0: 32x32 (no detections), 22.0ms
# 0: 32x32 (no detections), 18.2ms
# 0: 32x32 (no detections), 25.1ms
# 0: 32x32 (no detections), 28.2ms
# 0: 32x32 (no detections), 26.9ms
# 0: 32x32 (no detections), 25.0ms
# 0: 32x32 (no detections), 19.4ms
# 0: 32x32 (no detections), 25.3ms
# 0: 32x32 (no detections), 22.7ms
# 0: 32x32 (no detections), 23.5ms
# 0: 32x32 (no detections), 23.0ms
# 0: 32x32 (no detections), 25.9ms
# 0: 32x32 (no detections), 20.0ms
# 0: 32x32 (no detections), 21.0ms
# 0: 32x32 (no detections), 22.2ms
# 0: 32x32 (no detections), 20.7ms
# 0: 32x32 (no detections), 22.4ms
# 0: 32x32 (no detections), 21.7ms
# 0: 32x32 (no detections), 18.9ms
# 0: 32x32 (no detections), 18.5ms
# 0: 32x32 (no detections), 25.9ms
# 0: 32x32 (no detections), 19.2ms
# 0: 32x32 (no detections), 19.5ms
# 0: 32x32 (no detections), 17.6ms
# 0: 32x32 (no detections), 22.3ms
# 0: 32x32 (no detections), 18.5ms
# 0: 32x32 (no detections), 27.9ms
# 0: 32x32 (no detections), 27.0ms
# 0: 32x32 (no detections), 30.0ms
# 0: 32x32 (no detections), 27.3ms
# 0: 32x32 (no detections), 22.1ms
# 0: 32x32 (no detections), 20.5ms
# 0: 32x32 (no detections), 20.8ms
# 0: 32x32 (no detections), 21.4ms
# 0: 32x32 (no detections), 21.0ms
# 0: 32x32 (no detections), 21.4ms
# 0: 32x32 (no detections), 20.0ms
# 0: 32x32 (no detections), 20.8ms
# 0: 32x32 (no detections), 17.7ms
# 0: 32x32 (no detections), 20.4ms
# 0: 32x32 (no detections), 21.0ms
# 0: 32x32 (no detections), 16.6ms
# 0: 32x32 (no detections), 21.9ms
# 0: 32x32 (no detections), 18.6ms
# 0: 32x32 (no detections), 19.5ms
# 0: 32x32 (no detections), 22.8ms
# 0: 32x32 (no detections), 18.5ms
# 0: 32x32 (no detections), 19.0ms
# 0: 32x32 (no detections), 16.9ms
# 0: 32x32 (no detections), 20.3ms
# 0: 32x32 (no detections), 21.0ms
# 0: 32x32 (no detections), 21.0ms
# 0: 32x32 (no detections), 27.0ms
# 0: 32x32 (no detections), 27.6ms
# 0: 32x32 (no detections), 26.9ms
# 0: 32x32 (no detections), 28.2ms
# 0: 32x32 (no detections), 22.5ms
# 0: 32x32 (no detections), 20.7ms
# 0: 32x32 (no detections), 18.6ms
# 0: 32x32 (no detections), 22.8ms
# 0: 32x32 (no detections), 22.9ms
# 0: 32x32 (no detections), 25.3ms
# 0: 32x32 (no detections), 24.0ms
# 0: 32x32 (no detections), 24.0ms
# 0: 32x32 (no detections), 19.7ms
# 0: 32x32 (no detections), 23.9ms
# 0: 32x32 (no detections), 25.1ms
# 0: 32x32 (no detections), 20.9ms
# 0: 32x32 (no detections), 22.7ms
# 0: 32x32 (no detections), 22.0ms
# 0: 32x32 (no detections), 21.7ms
# 0: 32x32 (no detections), 18.0ms
# 0: 32x32 (no detections), 20.5ms
# 0: 32x32 (no detections), 25.5ms
# 0: 32x32 (no detections), 20.4ms
# 0: 32x32 (no detections), 21.7ms
# 0: 32x32 (no detections), 23.0ms
# 0: 32x32 (no detections), 21.6ms
# 0: 32x32 (no detections), 24.2ms
# 0: 32x32 (no detections), 26.1ms
# 0: 32x32 (no detections), 32.3ms
# 0: 32x32 (no detections), 25.0ms
# 0: 32x32 (no detections), 29.1ms
# 0: 32x32 (no detections), 30.9ms
# 0: 32x32 (no detections), 40.9ms
# 0: 32x32 (no detections), 22.3ms
# 0: 32x32 (no detections), 22.0ms
# 0: 32x32 (no detections), 23.1ms
# 0: 32x32 (no detections), 24.8ms
# 0: 32x32 (no detections), 23.9ms
# 0: 32x32 (no detections), 24.0ms
# 0: 32x32 (no detections), 21.7ms
# 0: 32x32 (no detections), 26.4ms
# 0: 32x32 (no detections), 25.5ms
# 0: 32x32 (no detections), 20.6ms
# 0: 32x32 (no detections), 21.6ms
# 0: 32x32 (no detections), 21.4ms
# 0: 32x32 (no detections), 21.7ms
# 0: 32x32 (no detections), 22.1ms
# 0: 32x32 (no detections), 23.3ms
# 0: 32x32 (no detections), 24.0ms
# 0: 32x32 (no detections), 24.1ms
# 0: 32x32 (no detections), 19.4ms
# 0: 32x32 (no detections), 20.2ms
# 0: 32x32 (no detections), 19.2ms
# 0: 32x32 (no detections), 20.9ms
# 0: 32x32 (no detections), 23.0ms
# 0: 32x32 (no detections), 22.9ms
# 0: 32x32 (no detections), 21.9ms
# 0: 32x32 (no detections), 22.4ms
# 0: 32x32 (no detections), 21.7ms
# 0: 32x32 (no detections), 24.9ms
# 0: 32x32 (no detections), 19.8ms
# 0: 32x32 (no detections), 33.2ms
# 0: 32x32 (no detections), 30.9ms
# 0: 32x32 (no detections), 56.3ms
# 0: 32x32 (no detections), 47.9ms
# 0: 32x32 (no detections), 27.9ms
# 0: 32x32 (no detections), 21.9ms
# 0: 32x32 (no detections), 21.8ms
# 0: 32x32 (no detections), 24.3ms
# 0: 32x32 (no detections), 21.8ms
# 0: 32x32 (no detections), 21.6ms
# 0: 32x32 (no detections), 19.0ms
# 0: 32x32 (no detections), 18.0ms
# 0: 32x32 (no detections), 21.0ms
# 0: 32x32 (no detections), 25.4ms
# 0: 32x32 (no detections), 20.9ms
# 0: 32x32 (no detections), 63.1ms
# 0: 32x32 (no detections), 29.0ms
# 0: 32x32 (no detections), 22.2ms
# 0: 32x32 (no detections), 22.4ms
# 0: 32x32 (no detections), 22.9ms
# 0: 32x32 (no detections), 19.4ms
# 0: 32x32 (no detections), 18.9ms
# 0: 32x32 (no detections), 23.6ms
# 0: 32x32 (no detections), 20.0ms
# 0: 32x32 (no detections), 22.9ms
# 0: 32x32 (no detections), 21.9ms
# 0: 32x32 (no detections), 22.7ms
# 0: 32x32 (no detections), 23.1ms
# 0: 32x32 (no detections), 20.7ms
# 0: 32x32 (no detections), 24.9ms
# 0: 32x32 (no detections), 29.0ms
# 0: 32x32 (no detections), 26.6ms
# 0: 32x32 (no detections), 28.9ms
# 0: 32x32 (no detections), 19.6ms
# 0: 32x32 (no detections), 19.3ms
# 0: 32x32 (no detections), 28.9ms
# 0: 32x32 (no detections), 29.2ms
# 0: 32x32 (no detections), 29.4ms
# 0: 32x32 (no detections), 31.9ms
# 0: 32x32 (no detections), 24.2ms
# 0: 32x32 (no detections), 22.0ms
# 0: 32x32 (no detections), 21.9ms
# 0: 32x32 (no detections), 23.9ms
# 0: 32x32 (no detections), 22.6ms
# 0: 32x32 (no detections), 30.3ms
# 0: 32x32 (no detections), 30.9ms
# 0: 32x32 (no detections), 28.9ms
# 0: 32x32 (no detections), 25.9ms
# 0: 32x32 (no detections), 27.0ms
# 0: 32x32 (no detections), 19.5ms
# 0: 32x32 (no detections), 20.8ms
# 0: 32x32 (no detections), 27.9ms
# 0: 32x32 (no detections), 29.7ms
# 0: 32x32 (no detections), 28.0ms
# 0: 32x32 (no detections), 30.0ms
# 0: 32x32 (no detections), 23.1ms
# 0: 32x32 (no detections), 23.3ms
# 0: 32x32 (no detections), 19.8ms
# 0: 32x32 (no detections), 21.4ms
# 0: 32x32 (no detections), 20.8ms
# 0: 32x32 (no detections), 26.3ms
# 0: 32x32 (no detections), 32.0ms
# 0: 32x32 (no detections), 30.9ms
# 0: 32x32 (no detections), 29.2ms
# 0: 32x32 (no detections), 33.4ms
# 0: 32x32 (no detections), 23.5ms
# 0: 32x32 (no detections), 27.1ms
# 0: 32x32 (no detections), 21.8ms
# 0: 32x32 (no detections), 22.5ms
# 0: 32x32 (no detections), 24.9ms
# 0: 32x32 (no detections), 24.0ms
# 0: 32x32 (no detections), 29.0ms
# 0: 32x32 (no detections), 28.9ms
# 0: 32x32 (no detections), 57.9ms
# 0: 32x32 (no detections), 62.7ms
# 0: 32x32 (no detections), 39.0ms
# 0: 32x32 (no detections), 21.0ms
# 0: 32x32 (no detections), 40.1ms
# 0: 32x32 (no detections), 24.2ms
# 0: 32x32 (no detections), 21.0ms
# 0: 32x32 (no detections), 26.2ms
# 0: 32x32 (no detections), 18.5ms
# 0: 32x32 (no detections), 25.7ms
# 0: 32x32 (no detections), 30.6ms
# 0: 32x32 (no detections), 27.0ms
# 0: 32x32 (no detections), 23.4ms
# 0: 32x32 (no detections), 21.1ms
# 0: 32x32 (no detections), 19.9ms
# 0: 32x32 (no detections), 26.3ms
# 0: 32x32 (no detections), 23.7ms
# 0: 32x32 (no detections), 21.3ms
# 0: 32x32 (no detections), 24.9ms
# 0: 32x32 (no detections), 20.2ms
# 0: 32x32 (no detections), 26.6ms
# 0: 32x32 (no detections), 25.3ms
# 0: 32x32 (no detections), 32.3ms
# 0: 32x32 (no detections), 31.9ms
# 0: 32x32 (no detections), 27.0ms
# 0: 32x32 (no detections), 35.4ms
# 0: 32x32 (no detections), 21.8ms
# 0: 32x32 (no detections), 25.0ms
# 0: 32x32 (no detections), 20.8ms
# 0: 32x32 (no detections), 24.3ms
# 0: 32x32 (no detections), 19.4ms
# 0: 32x32 (no detections), 23.9ms
# 0: 32x32 (no detections), 19.4ms
# 0: 32x32 (no detections), 20.0ms
# 0: 32x32 (no detections), 25.5ms
# 0: 32x32 (no detections), 19.6ms
# 0: 32x32 (no detections), 21.3ms
# 0: 32x32 (no detections), 21.4ms
# 0: 32x32 (no detections), 30.7ms
# 0: 32x32 (no detections), 26.4ms
# 0: 32x32 (no detections), 28.0ms
# 0: 32x32 (no detections), 27.9ms
# 0: 32x32 (no detections), 19.8ms
# 0: 32x32 (no detections), 20.6ms
# 0: 32x32 (no detections), 18.0ms
# 0: 32x32 (no detections), 21.9ms
# 0: 32x32 (no detections), 20.0ms
# 0: 32x32 (no detections), 23.6ms
# 0: 32x32 (no detections), 21.1ms
# 0: 32x32 (no detections), 21.3ms
# 0: 32x32 (no detections), 23.0ms
# 0: 32x32 (no detections), 32.9ms
# 0: 32x32 (no detections), 27.3ms
# 0: 32x32 (no detections), 26.9ms
# 0: 32x32 (no detections), 28.3ms
# 0: 32x32 (no detections), 61.9ms
# 0: 32x32 (no detections), 714.8ms
# 0: 32x32 (no detections), 24.2ms
# 0: 32x32 (no detections), 25.0ms
# 0: 32x32 (no detections), 245.1ms
# 0: 32x32 (no detections), 82.5ms
# 0: 32x32 (no detections), 28.0ms
# 0: 32x32 (no detections), 17.0ms
# 0: 32x32 (no detections), 19.4ms
# 0: 32x32 (no detections), 19.5ms
# 0: 32x32 (no detections), 19.0ms
# 0: 32x32 (no detections), 19.9ms
# 0: 32x32 (no detections), 279.6ms
# 0: 32x32 (no detections), 56.2ms
# 0: 32x32 (no detections), 29.6ms
# 0: 32x32 (no detections), 28.2ms
# 0: 32x32 (no detections), 37.7ms
# 0: 32x32 (no detections), 19.3ms
# 0: 32x32 (no detections), 23.1ms
# 0: 32x32 (no detections), 22.8ms
# 0: 32x32 (no detections), 21.4ms
# 0: 32x32 (no detections), 26.0ms
# 0: 32x32 (no detections), 34.0ms
# 0: 32x32 (no detections), 27.1ms
# 0: 32x32 (no detections), 62.8ms
# 0: 32x32 (no detections), 25.4ms
# 0: 32x32 (no detections), 24.8ms
# 0: 32x32 (no detections), 22.1ms
# 0: 32x32 (no detections), 17.0ms
# 0: 32x32 (no detections), 25.9ms
# 0: 32x32 (no detections), 25.9ms
# 0: 32x32 (no detections), 25.9ms
# 0: 32x32 (no detections), 24.9ms
# 0: 32x32 (no detections), 18.2ms
# 0: 32x32 (no detections), 23.8ms
# 0: 32x32 (no detections), 30.1ms
# 0: 32x32 (no detections), 28.6ms
# 0: 32x32 (no detections), 46.7ms
# 0: 32x32 (no detections), 37.0ms
# 0: 32x32 (no detections), 28.0ms
# 0: 32x32 (no detections), 42.0ms
# 0: 32x32 (no detections), 72.1ms
# 0: 32x32 (no detections), 45.5ms
# 0: 32x32 (no detections), 17.4ms
# 0: 32x32 (no detections), 22.6ms
# 0: 32x32 (no detections), 25.7ms
# 0: 32x32 (no detections), 24.7ms
# 0: 32x32 (no detections), 23.0ms
# 0: 32x32 (no detections), 25.9ms
# 0: 32x32 (no detections), 18.1ms
# 0: 32x32 (no detections), 21.8ms
# 0: 32x32 (no detections), 21.2ms
# 0: 32x32 (no detections), 23.9ms
# 0: 32x32 (no detections), 24.9ms
# 0: 32x32 (no detections), 23.2ms
# 0: 32x32 (no detections), 15.0ms
# 0: 32x32 (no detections), 18.0ms
# 0: 32x32 (no detections), 16.6ms
# 0: 32x32 (no detections), 25.1ms
# 0: 32x32 (no detections), 23.7ms
# 0: 32x32 (no detections), 28.9ms
# 0: 32x32 (no detections), 38.3ms
# 0: 32x32 (no detections), 23.8ms
# 0: 32x32 (no detections), 24.1ms
# 0: 32x32 (no detections), 18.9ms
# 0: 32x32 (no detections), 25.0ms
# 0: 32x32 (no detections), 23.7ms
# 0: 32x32 (no detections), 21.9ms
# 0: 32x32 (no detections), 20.0ms
# 0: 32x32 (no detections), 39.4ms
# 0: 32x32 (no detections), 45.9ms
# 0: 32x32 (no detections), 37.8ms
# 0: 32x32 (no detections), 35.4ms
# 0: 32x32 (no detections), 34.0ms
# 0: 32x32 (no detections), 35.2ms
# 0: 32x32 (no detections), 34.0ms
# 0: 32x32 (no detections), 36.6ms
# 0: 32x32 (no detections), 56.5ms
# 0: 32x32 (no detections), 58.5ms
# 0: 32x32 (no detections), 59.2ms
# 0: 32x32 (no detections), 33.5ms
# 0: 32x32 (no detections), 40.0ms
# 0: 32x32 (no detections), 37.3ms
# 0: 32x32 (no detections), 34.2ms
# 0: 32x32 (no detections), 26.7ms
# 0: 32x32 (no detections), 33.5ms
# 0: 32x32 (no detections), 50.3ms
# 0: 32x32 (no detections), 53.5ms
# 0: 32x32 (no detections), 36.1ms
# 0: 32x32 (no detections), 32.1ms
# 0: 32x32 (no detections), 20.0ms
# 0: 32x32 (no detections), 26.9ms
# 0: 32x32 (no detections), 26.8ms
# 0: 32x32 (no detections), 20.3ms
# 0: 32x32 (no detections), 21.0ms
# 0: 32x32 (no detections), 21.8ms
# 0: 32x32 (no detections), 24.6ms
# 0: 32x32 (no detections), 25.1ms
# 0: 32x32 (no detections), 23.8ms
# 0: 32x32 (no detections), 45.7ms
# 0: 32x32 (no detections), 28.9ms
# 0: 32x32 (no detections), 29.0ms
# 0: 32x32 (no detections), 30.9ms
# 0: 32x32 (no detections), 29.8ms
# 0: 32x32 (no detections), 29.3ms
# 0: 32x32 (no detections), 25.0ms
# 0: 32x32 (no detections), 21.4ms
# 0: 32x32 (no detections), 27.7ms
# 0: 32x32 (no detections), 25.9ms
# 0: 32x32 (no detections), 19.8ms
# 0: 32x32 (no detections), 18.9ms
# 0: 32x32 (no detections), 19.0ms
# 0: 32x32 (no detections), 20.9ms
# 0: 32x32 (no detections), 26.8ms
# 0: 32x32 (no detections), 29.2ms
# 0: 32x32 (no detections), 29.1ms
# 0: 32x32 (no detections), 20.9ms
# 0: 32x32 (no detections), 27.6ms
# 0: 32x32 (no detections), 30.3ms
# 0: 32x32 (no detections), 21.5ms
# 0: 32x32 (no detections), 26.4ms
# 0: 32x32 (no detections), 20.9ms
# 0: 32x32 (no detections), 22.0ms
# 0: 32x32 (no detections), 25.0ms
# 0: 32x32 (no detections), 23.4ms
# 0: 32x32 (no detections), 25.9ms
# 0: 32x32 (no detections), 20.1ms
# 0: 32x32 (no detections), 21.5ms
# 0: 32x32 (no detections), 21.7ms
# 0: 32x32 (no detections), 23.4ms
# 0: 32x32 (no detections), 26.9ms
# 0: 32x32 (no detections), 27.9ms
# 0: 32x32 (no detections), 31.8ms
# 0: 32x32 (no detections), 27.4ms
# 0: 32x32 (no detections), 23.9ms
# 0: 32x32 (no detections), 30.8ms
# 0: 32x32 (no detections), 21.1ms
# 0: 32x32 (no detections), 32.9ms
# 0: 32x32 (no detections), 20.9ms
# 0: 32x32 (no detections), 20.5ms
# 0: 32x32 (no detections), 23.8ms
# 0: 32x32 (no detections), 21.2ms
# 0: 32x32 (no detections), 20.3ms
# 0: 32x32 (no detections), 20.6ms
# 0: 32x32 (no detections), 20.6ms
# 0: 32x32 (no detections), 19.0ms
# 0: 32x32 (no detections), 20.8ms
# 0: 32x32 (no detections), 26.0ms
# 0: 32x32 (no detections), 28.3ms
# 0: 32x32 (no detections), 28.8ms
# 0: 32x32 (no detections), 26.9ms
# 0: 32x32 (no detections), 27.8ms
# 0: 32x32 (no detections), 22.8ms
# 0: 32x32 (no detections), 24.9ms
# 0: 32x32 (no detections), 28.2ms
# 0: 32x32 (no detections), 23.9ms
# 0: 32x32 (no detections), 29.0ms
# 0: 32x32 (no detections), 21.4ms
# 0: 32x32 (no detections), 22.2ms
# 0: 32x32 (no detections), 21.2ms
# 0: 32x32 (no detections), 30.0ms
# 0: 32x32 (no detections), 30.5ms
# 0: 32x32 (no detections), 30.1ms
# 0: 32x32 (no detections), 41.9ms
# 0: 32x32 (no detections), 42.3ms
# 0: 32x32 (no detections), 34.4ms
# 0: 32x32 (no detections), 38.7ms
# 0: 32x32 (no detections), 33.1ms
# 0: 32x32 (no detections), 153.3ms
# 0: 32x32 (no detections), 24.7ms
# 0: 32x32 (no detections), 23.0ms
# 0: 32x32 (no detections), 30.0ms
# 0: 32x32 (no detections), 31.0ms
# 0: 32x32 (no detections), 30.9ms
# 0: 32x32 (no detections), 33.2ms
# 0: 32x32 (no detections), 20.0ms
# 0: 32x32 (no detections), 19.2ms
# 0: 32x32 (no detections), 34.0ms
# 0: 32x32 (no detections), 48.0ms
# 0: 32x32 (no detections), 51.7ms
# 0: 32x32 (no detections), 47.8ms
# 0: 32x32 (no detections), 59.9ms
# 0: 32x32 (no detections), 44.5ms
# 0: 32x32 (no detections), 26.6ms
# 0: 32x32 (no detections), 24.9ms
# 0: 32x32 (no detections), 25.3ms
# 0: 32x32 (no detections), 21.1ms
# 0: 32x32 (no detections), 23.4ms
# 0: 32x32 (no detections), 25.7ms
# 0: 32x32 (no detections), 25.9ms
# 0: 32x32 (no detections), 27.4ms
# 0: 32x32 (no detections), 22.9ms
# 0: 32x32 (no detections), 22.1ms
# 0: 32x32 (no detections), 19.0ms
# 0: 32x32 (no detections), 20.6ms
# 0: 32x32 (no detections), 20.0ms
# 0: 32x32 (no detections), 26.2ms
# 0: 32x32 (no detections), 26.8ms
# 0: 32x32 (no detections), 28.6ms
# 0: 32x32 (no detections), 26.4ms
# 0: 32x32 (no detections), 24.1ms
# ...
# 0: 32x32 (no detections), 18.2ms
# 0: 32x32 (no detections), 21.1ms
# 0: 32x32 (no detections), 18.4ms
# 0: 32x32 (no detections), 23.0ms
# 0: 32x32 (no detections), 20.7ms
# 0: 32x32 (no detections), 20.8ms
# 0: 32x32 (no detections), 22.5ms
# 0: 32x32 (no detections), 22.7ms
# 0: 32x32 (no detections), 23.2ms
# 0: 32x32 (no detections), 21.0ms
# 0: 32x32 (no detections), 27.0ms
# 0: 32x32 (no detections), 37.0ms
# 0: 32x32 (no detections), 32.7ms
# 0: 32x32 (no detections), 25.8ms
# 0: 32x32 (no detections), 28.3ms
# 0: 32x32 (no detections), 27.9ms
# 0: 32x32 (no detections), 43.9ms
# 0: 32x32 (no detections), 34.1ms
# 0: 32x32 (no detections), 26.4ms
# 0: 32x32 (no detections), 23.9ms
# 0: 32x32 (no detections), 30.4ms
# 0: 32x32 (no detections), 32.0ms
# 0: 32x32 (no detections), 25.0ms
# 0: 32x32 (no detections), 26.1ms
# 0: 32x32 (no detections), 22.5ms
# 0: 32x32 (no detections), 22.9ms
# 0: 32x32 (no detections), 21.9ms
# 0: 32x32 (no detections), 22.7ms
# 0: 32x32 (no detections), 21.9ms
# 0: 32x32 (no detections), 21.8ms
# 0: 32x32 (no detections), 22.9ms
# 0: 32x32 (no detections), 24.9ms
# 0: 32x32 (no detections), 27.4ms
# 0: 32x32 (no detections), 28.1ms
# 0: 32x32 (no detections), 25.6ms
# 0: 32x32 (no detections), 24.6ms
# 0: 32x32 (no detections), 26.2ms
# 0: 32x32 (no detections), 26.9ms
# 0: 32x32 (no detections), 27.2ms
# 0: 32x32 (no detections), 21.8ms
# 0: 32x32 (no detections), 20.0ms
# 0: 32x32 (no detections), 21.7ms
# 0: 32x32 (no detections), 21.9ms
# 0: 32x32 (no detections), 29.2ms
# 0: 32x32 (no detections), 31.2ms
# 0: 32x32 (no detections), 30.1ms
# 0: 32x32 (no detections), 34.8ms
# 0: 32x32 (no detections), 27.5ms
# 0: 32x32 (no detections), 22.1ms
# 0: 32x32 (no detections), 27.0ms
# 0: 32x32 (no detections), 34.8ms
# 0: 32x32 (no detections), 31.8ms
# 0: 32x32 (no detections), 36.5ms
# 0: 32x32 (no detections), 29.0ms
# 0: 32x32 (no detections), 25.0ms
# 0: 32x32 (no detections), 22.1ms
# 0: 32x32 (no detections), 32.8ms
# 0: 32x32 (no detections), 31.4ms
# 0: 32x32 (no detections), 32.9ms
# 0: 32x32 (no detections), 31.1ms
# 0: 32x32 (no detections), 26.0ms
# 0: 32x32 (no detections), 24.3ms
# 0: 32x32 (no detections), 25.0ms
# 0: 32x32 (no detections), 27.6ms
# 0: 32x32 (no detections), 24.5ms
# 0: 32x32 (no detections), 41.0ms
# 0: 32x32 (no detections), 31.4ms
# 0: 32x32 (no detections), 34.0ms
# 0: 32x32 (no detections), 29.6ms
# 0: 32x32 (no detections), 27.8ms
# 0: 32x32 (no detections), 21.9ms
# 0: 32x32 (no detections), 24.9ms
# 0: 32x32 (no detections), 26.9ms
# 0: 32x32 (no detections), 31.0ms
# 0: 32x32 (no detections), 35.2ms
# 0: 32x32 (no detections), 35.9ms
# 0: 32x32 (no detections), 30.9ms
# 0: 32x32 (no detections), 25.2ms
# 0: 32x32 (no detections), 23.9ms
# 0: 32x32 (no detections), 19.9ms
# 0: 32x32 (no detections), 18.9ms
# 0: 32x32 (no detections), 27.7ms
# 0: 32x32 (no detections), 21.5ms
# 0: 32x32 (no detections), 28.9ms
# 0: 32x32 (no detections), 30.1ms
# 0: 32x32 (no detections), 31.7ms
# 0: 32x32 (no detections), 32.4ms
# 0: 32x32 (no detections), 30.2ms
# 0: 32x32 (no detections), 26.2ms
# 0: 32x32 (no detections), 21.2ms
# 0: 32x32 (no detections), 24.3ms
# 0: 32x32 (no detections), 21.9ms
# 0: 32x32 (no detections), 22.0ms
# 0: 32x32 (no detections), 21.5ms
# 0: 32x32 (no detections), 27.9ms
# 0: 32x32 (no detections), 31.9ms
# 0: 32x32 (no detections), 53.1ms
# 0: 32x32 (no detections), 27.1ms
# 0: 32x32 (no detections), 30.1ms
# 0: 32x32 (no detections), 31.9ms
# 0: 32x32 (no detections), 46.2ms
# 0: 32x32 (no detections), 30.9ms
# 0: 32x32 (no detections), 26.1ms
# 0: 32x32 (no detections), 24.1ms
# 0: 32x32 (no detections), 20.7ms
# 0: 32x32 (no detections), 33.9ms
# 0: 32x32 (no detections), 30.5ms
# 0: 32x32 (no detections), 42.3ms
# 0: 32x32 (no detections), 54.0ms
# 0: 32x32 (no detections), 63.4ms
# 0: 32x32 (no detections), 37.9ms
# 0: 32x32 (no detections), 23.4ms
# 0: 32x32 (no detections), 26.1ms
# 0: 32x32 (no detections), 26.0ms
# 0: 32x32 (no detections), 21.9ms
# 0: 32x32 (no detections), 29.8ms
# 0: 32x32 (no detections), 30.8ms
# 0: 32x32 (no detections), 32.9ms
# 0: 32x32 (no detections), 32.6ms
# 0: 32x32 (no detections), 25.3ms
# 0: 32x32 (no detections), 24.9ms
# 0: 32x32 (no detections), 24.5ms
# 0: 32x32 (no detections), 23.9ms
# 0: 32x32 (no detections), 27.3ms
# 0: 32x32 (no detections), 19.9ms
# 0: 32x32 (no detections), 21.7ms
# 0: 32x32 (no detections), 40.2ms
# 0: 32x32 (no detections), 28.8ms
# 0: 32x32 (no detections), 31.0ms
# 0: 32x32 (no detections), 30.9ms
# 0: 32x32 (no detections), 25.2ms
# 0: 32x32 (no detections), 25.0ms
# 0: 32x32 (no detections), 22.3ms
# 0: 32x32 (no detections), 22.5ms
# 0: 32x32 (no detections), 28.9ms
# 0: 32x32 (no detections), 28.5ms
# 0: 32x32 (no detections), 29.9ms
# 0: 32x32 (no detections), 35.9ms
# 0: 32x32 (no detections), 36.9ms
# 0: 32x32 (no detections), 35.5ms
# 0: 32x32 (no detections), 26.0ms
# 0: 32x32 (no detections), 25.7ms
# 0: 32x32 (no detections), 25.6ms
# 0: 32x32 (no detections), 85.3ms
# 0: 32x32 (no detections), 20.8ms
# 0: 32x32 (no detections), 26.0ms
# 0: 32x32 (no detections), 26.0ms
# 0: 32x32 (no detections), 21.1ms
# 0: 32x32 (no detections), 29.1ms
# 0: 32x32 (no detections), 30.4ms
# 0: 32x32 (no detections), 31.6ms
# 0: 32x32 (no detections), 32.0ms
# 0: 32x32 (no detections), 29.6ms
# 0: 32x32 (no detections), 21.0ms
# 0: 32x32 (no detections), 33.5ms
# 0: 32x32 (no detections), 20.8ms
# 0: 32x32 (no detections), 20.3ms
# 0: 32x32 (no detections), 20.5ms
# 0: 32x32 (no detections), 21.9ms
# 0: 32x32 (no detections), 24.0ms
# 0: 32x32 (no detections), 41.9ms
# 0: 32x32 (no detections), 50.4ms
# 0: 32x32 (no detections), 30.9ms
# 0: 32x32 (no detections), 20.2ms
# 0: 32x32 (no detections), 30.0ms
# 0: 32x32 (no detections), 26.1ms
# 0: 32x32 (no detections), 27.6ms
# 0: 32x32 (no detections), 22.9ms
# 0: 32x32 (no detections), 19.9ms
# 0: 32x32 (no detections), 28.1ms
# 0: 32x32 (no detections), 24.5ms
# 0: 32x32 (no detections), 21.3ms
# 0: 32x32 (no detections), 23.9ms
# 0: 32x32 (no detections), 23.8ms
# 0: 32x32 (no detections), 24.8ms
# 0: 32x32 (no detections), 23.9ms
# 0: 32x32 (no detections), 21.0ms
# 0: 32x32 (no detections), 22.9ms
# 0: 32x32 (no detections), 27.9ms
# 0: 32x32 (no detections), 24.6ms
# 0: 32x32 (no detections), 35.1ms
# 0: 32x32 (no detections), 30.3ms
# 0: 32x32 (no detections), 26.9ms
# 0: 32x32 (no detections), 28.0ms
# 0: 32x32 (no detections), 30.1ms
# 0: 32x32 (no detections), 20.7ms
# 0: 32x32 (no detections), 30.9ms
# 0: 32x32 (no detections), 22.0ms
# 0: 32x32 (no detections), 21.9ms
# 0: 32x32 (no detections), 19.4ms
# 0: 32x32 (no detections), 21.0ms
# 0: 32x32 (no detections), 19.7ms
# 0: 32x32 (no detections), 25.4ms
# 0: 32x32 (no detections), 20.0ms
# 0: 32x32 (no detections), 22.2ms
# 0: 32x32 (no detections), 25.0ms
# 0: 32x32 (no detections), 26.8ms
# 0: 32x32 (no detections), 34.5ms
# 0: 32x32 (no detections), 27.6ms
# 0: 32x32 (no detections), 28.5ms
# 0: 32x32 (no detections), 33.0ms
# 0: 32x32 (no detections), 27.1ms
# 0: 32x32 (no detections), 21.0ms
# 0: 32x32 (no detections), 17.1ms
# 0: 32x32 (no detections), 19.0ms
# 0: 32x32 (no detections), 18.5ms
# 0: 32x32 (no detections), 17.9ms
# 0: 32x32 (no detections), 18.5ms
# 0: 32x32 (no detections), 23.0ms
# 0: 32x32 (no detections), 41.0ms
# 0: 32x32 (no detections), 25.4ms
# 0: 32x32 (no detections), 60.3ms
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# d:\repository\face_recognition\model.ipynb Cell 14 line 1
# ----> <a href='vscode-notebook-cell:/d%3A/repository/face_recognition/model.ipynb#X15sZmlsZQ%3D%3D?line=0'>1</a> model.predict(source="0",show=True,conf=0.5)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\ultralytics\engine\model.py:236, in Model.predict(self, source, stream, predictor, **kwargs)
#     234 if prompts and hasattr(self.predictor, 'set_prompts'):  # for SAM-type models
#     235     self.predictor.set_prompts(prompts)
# --> 236 return self.predictor.predict_cli(source=source) if is_cli else self.predictor(source=source, stream=stream)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\ultralytics\engine\predictor.py:194, in BasePredictor.__call__(self, source, model, stream, *args, **kwargs)
#     192     return self.stream_inference(source, model, *args, **kwargs)
#     193 else:
# --> 194     return list(self.stream_inference(source, model, *args, **kwargs))
#
# File ~\AppData\Roaming\Python\Python310\site-packages\torch\utils\_contextlib.py:56, in _wrap_generator.<locals>.generator_context(*args, **kwargs)
#      53         else:
#      54             # Pass the last request to the generator and get its response
#      55             with ctx_factory():
# ---> 56                 response = gen.send(request)
#      58 # We let the exceptions raised above by the generator's `.throw` or
#      59 # `.send` methods bubble up to our caller, except for StopIteration
#      60 except StopIteration as e:
#      61     # The generator informed us that it is done: take whatever its
#      62     # returned value (if any) was and indicate that we're done too
#      63     # by returning it (see docs for python's return-statement).
#
# File ~\AppData\Roaming\Python\Python310\site-packages\ultralytics\engine\predictor.py:253, in BasePredictor.stream_inference(self, source, model, *args, **kwargs)
#     251 # Inference
#     252 with profilers[1]:
# --> 253     preds = self.inference(im, *args, **kwargs)
#     255 # Postprocess
#     256 with profilers[2]:
#
# File ~\AppData\Roaming\Python\Python310\site-packages\ultralytics\engine\predictor.py:133, in BasePredictor.inference(self, im, *args, **kwargs)
#     130 def inference(self, im, *args, **kwargs):
#     131     visualize = increment_path(self.save_dir / Path(self.batch[0][0]).stem,
#     132                                mkdir=True) if self.args.visualize and (not self.source_type.tensor) else False
# --> 133     return self.model(im, augment=self.args.augment, visualize=visualize)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\torch\nn\modules\module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~\AppData\Roaming\Python\Python310\site-packages\ultralytics\nn\autobackend.py:333, in AutoBackend.forward(self, im, augment, visualize)
#     330     im = im.permute(0, 2, 3, 1)  # torch BCHW to numpy BHWC shape(1,320,192,3)
#     332 if self.pt or self.nn_module:  # PyTorch
# --> 333     y = self.model(im, augment=augment, visualize=visualize) if augment or visualize else self.model(im)
#     334 elif self.jit:  # TorchScript
#     335     y = self.model(im)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\torch\nn\modules\module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~\AppData\Roaming\Python\Python310\site-packages\ultralytics\nn\tasks.py:45, in BaseModel.forward(self, x, *args, **kwargs)
#      43 if isinstance(x, dict):  # for cases of training and validating while training.
#      44     return self.loss(x, *args, **kwargs)
# ---> 45 return self.predict(x, *args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\ultralytics\nn\tasks.py:62, in BaseModel.predict(self, x, profile, visualize, augment)
#      60 if augment:
#      61     return self._predict_augment(x)
# ---> 62 return self._predict_once(x, profile, visualize)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\ultralytics\nn\tasks.py:82, in BaseModel._predict_once(self, x, profile, visualize)
#      80 if profile:
#      81     self._profile_one_layer(m, x, dt)
# ---> 82 x = m(x)  # run
#      83 y.append(x if m.i in self.save else None)  # save output
#      84 if visualize:
#
# File ~\AppData\Roaming\Python\Python310\site-packages\torch\nn\modules\module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~\AppData\Roaming\Python\Python310\site-packages\ultralytics\nn\modules\block.py:182, in C2f.forward(self, x)
#     180 y = list(self.cv1(x).chunk(2, 1))
#     181 y.extend(m(y[-1]) for m in self.m)
# --> 182 return self.cv2(torch.cat(y, 1))
#
# File ~\AppData\Roaming\Python\Python310\site-packages\torch\nn\modules\module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~\AppData\Roaming\Python\Python310\site-packages\ultralytics\nn\modules\conv.py:42, in Conv.forward_fuse(self, x)
#      40 def forward_fuse(self, x):
#      41     """Perform transposed convolution of 2D data."""
# ---> 42     return self.act(self.conv(x))
#
# File ~\AppData\Roaming\Python\Python310\site-packages\torch\nn\modules\module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~\AppData\Roaming\Python\Python310\site-packages\torch\nn\modules\conv.py:463, in Conv2d.forward(self, input)
#     462 def forward(self, input: Tensor) -> Tensor:
# --> 463     return self._conv_forward(input, self.weight, self.bias)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\torch\nn\modules\conv.py:459, in Conv2d._conv_forward(self, input, weight, bias)
#     455 if self.padding_mode != 'zeros':
#     456     return F.conv2d(F.pad(input, self._reversed_padding_repeated_twice, mode=self.padding_mode),
#     457                     weight, bias, self.stride,
#     458                     _pair(0), self.dilation, self.groups)
# --> 459 return F.conv2d(input, weight, bias, self.stride,
#     460                 self.padding, self.dilation, self.groups)
#
# KeyboardInterrupt:
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
# Out:
# ;
